# %% [markdown]
# ## 1. Upload your .CSV file
# ####Select the folder icon on the column to the left, then select the paper icon with an upwards arrow to upload your CSV file.
#
# #### Optionally, follow step 1 and drag your file to the column to upload it.
#
# <img src="https://drive.google.com/uc?id=1a9QqqN0gpwOsrmlXD0gEfh_7MoKlkqpV">
#
#
# ####Please remember to use the official format convention as told by the GitHub repository.

# %% [markdown]
# ##2. Run
#
# ####Please execute this cell by pressing the button below to run MHCFlurry. This will easily generate immunogenic scores for peptides/alleles and will be stored on your computer in the shape of an .csv file that stores everything.

# %%
# !git clone https://github.com/elmerfer/ITSNdb
# !mv ITSNdb/Colab/MHCFlurry.py MHCFlurry.py
import MHCFlurry as mhc
ma = mhc.install()
c = mhc.run()
# Out:
# Converting CSV
# Processing
# Success! Downloading your CSV shortly...
# Downloaded on your local computer. Name: "Neoantigen_Table_example_MHC_results.csv"

# %%
#A typical result will look like this:
# Out:
#        Sample Neoantigen         HLA  mhcflurry_affinity  \
# 0      AL4602  QGAARRQQL  HLA-B08:01           80.901691
# 1      AL4602  MLDDFKRFK  HLA-A03:01           83.583239
# 2      AL4602  ALQRMSVVL  HLA-A32:01         1899.209737
# 3      AL4602  QRMSVVLAW  HLA-C07:02          131.522302
# 4      AL4602  QVFRNHLSR  HLA-A03:01          181.488435
# ...       ...        ...         ...                 ...
# 59278  PR4092  FPDKLRDKL  HLA-C12:03         1269.702811
# 59279  PR4092  FQHLYALVL  HLA-C12:03          123.028995
# 59280  PR4092  FLYQLNPRL  HLA-C12:03          186.326020
# 59281  PR4092  SRLQQFDVM  HLA-C07:01           46.089638
# 59282  PR4092  SRLNYIVLI  HLA-C07:01           41.022227
#
#        mhcflurry_affinity_percentile  mhcflurry_processing_score  \
# 0                           0.128125                    0.004678
# 1                           0.335875                    0.060677
# 2                           2.371500                    0.105013
# 3                           0.767000                    0.434900
# 4                           0.612625                    0.212345
# ...                              ...                         ...
# 59278                       3.706000                    0.406982
# 59279                       0.902750                    0.455656
# 59280                       1.310375                    0.661543
# 59281                       0.076625                    0.256509
# 59282                       0.043125                    0.914098
#
#        mhcflurry_presentation_score  mhcflurry_presentation_percentile
# 0                          0.518263                           0.783315
# 1                          0.559601                           0.694946
# 2                          0.066766                           3.996902
# 3                          0.754590                           0.351359
# 4                          0.505756                           0.808750
# ...                             ...                                ...
# 59278                      0.235422                           1.637174
# 59279                      0.779289                           0.310707
# 59280                      0.830164                           0.230027
# 59281                      0.819154                           0.248152
# 59282                      0.981116                           0.006168
#
# [59283 rows x 8 columns]
